# %%
import pandas as pd

df = pd.read_csv(
    'NTOT2024_01\\NTOT2024_01.csv',
    encoding='latin_1',
    sep=';',
    decimal=',',   # Interprets ',' as the decimal separator
    thousands='.'  # Removes '.' as a thousands separator
)
# Out:
# C:\Users\Ouarhim Younes\AppData\Local\Temp\ipykernel_23844\200548261.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
print(df[df['l_fac_top'] == '0-Régime Général stricto-sensu']['rem_mon'].sum())
# Out:
# 9801982099.07

# %%
df.columns
# Out:
# Index(['PRS_FAC_TOP', 'l_fac_top', 'l_serie', 'SERIE', 'prs_nat', 'l_prs_nat',
#        'rem_date', 'sns_date', 'asu_nat', 'l_asu_nat', 'cpl_cod', 'l_cpl_cod',
#        'REM_TAU', 'pre_spe', 'l_pre_spe', 'pre_spe1', 'l_pre_spe1', 'pre_stj1',
#        'l_pre_stj1', 'exe_spe', 'l_exe_spe', 'exe_spe1', 'l_exe_spe1',
#        'exe_stj1', 'l_exe_stj1', 'rem_mon', 'rec_mon', 'dep_mon', 'act_dnb',
#        'act_coe'],
#       dtype='object')

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(column)
        print(df[column].unique())
        print()
# Out:
# l_fac_top
# ['0-Régime Général stricto-sensu' '1-Ex-RSI']
#
# l_serie
# ['C Omnipraticiens' 'C Urgences Omnipraticiens' 'C Spécialistes'
#  'C Urgences Spécialistes' 'C Neuropsychiatres' 'C Dentistes'
#  'C Sages-femmes' 'C Spécifique des Cardiologues' 'C autres'
#  'Rémunération suivi personnes âgées C'
#  'Rémunération suivi personnes âgées V' 'V Omnipraticiens'
#  'V Spécialistes' 'V Neuropsychiatres' 'V Dentistes' 'V Sages-femmes'
#  'V MD' 'Rémunération pour certificat de décès' 'Actes en K'
#  "Actes d'échographie en ADE et K E" 'Actes en KC, KCC'
#  'Actes de chirurgie ADC' "Actes d'obstétrique ACO"
#  "Actes d'anesthésie ADA" "Actes d'écographie ADE"
#  'Actes techniques médicaux ATM' 'Z Radiodiagnostic-gastro-entérologues'
#  'Z autres médecins' 'Z Dentistes' "Actes d'imagerie ADI"
#  'Urgences Imagerie' 'Urgences Biologie - Médecins'
#  'SCM Soins conservateurs des stomatologues'
#  'PRO Prothèses dentaires des stomatologues'
# ...
